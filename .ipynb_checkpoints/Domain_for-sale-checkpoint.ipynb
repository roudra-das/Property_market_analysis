# %% [markdown]
# #  Extracting data from properties on the market with Domain api
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Roudra Das    roudra.das@gmail.com                                            |
# | External References   | <a href="https://api.domain.com.au/" target="_blank">Domain API</a>|
# | Input Datasets        |  List For Sale |
# | Output Datasets       |  Table|
# | Input Data Source     |  API |
# | Output Data Source    | Pandas Dataframe |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 15th May 2021 | Roudra Das | Notebook created to analyze properties that are on the listed in Australia|
#
# ## Other Details
# This Notebook is a prototype.

# %%
import pandas as pd
import requests
import json
import re, string, timeit
import time

# %%
pd.options.display.max_columns = None # show all columns in display

# %% [markdown]
# ## Functions

# %%
def get_api_key(api_key_id = "Domain"):
  """
  Get the api key for website accessing.

  Table of key type and key value for privacy.

  Parameters
  ----------
  @api_key_id [string]: Key value in dataframe

  Returns
  -------
  [string]: client_id & client_secret

  """
  # load api keys file
  df_api_keys = pd.read_csv('../../api_keys.csv', header = 'infer')
  
  # return api key if in dataset
  try:
    # get api key from id
    client_id = df_api_keys.loc[df_api_keys['Id'] == api_key_id]['Client'].iloc[0] # get client by id
    client_secret = df_api_keys.loc[df_api_keys['Id'] == api_key_id]['Secret'].iloc[0] # get secret by id
    # return api key
    return client_id, client_secret
  except IndexError:
    # get api key id list
    api_key_id_list = df_api_keys['Id'].unique().tolist()
    # print error message
    print('Cannot map key. Api key id must be one of the following options {0}'.format(api_key_id_list))

# %%
def api_property_list_for_sale(auth, property_type, bedrooms, bathrooms, suburb, postcode):
  # url for api
  url = "https://api.domain.com.au/v1/listings/residential/_search"

  # enter parameters
  post_fields ={
      "listingType":"Sale",
        "maxPrice":"",
        "pageSize":200,
      "propertyTypes":property_type,
      "minBedrooms":"",
        "maxBedrooms":"",
      "minBathrooms":"",
        "maxBathrooms":"",
      "locations":[
        {
          "state":"",
          "region":"",
          "area":"",
          "suburb":suburb,
          "postCode":postcode,
          "includeSurroundingSuburbs":False
        }
      ]
    }

  # response
  response = requests.post(url,headers=auth,json=post_fields)
  #response = requests.request("GET", url, headers=headers, params=querystring)
  return response.json()

# %%
def process_list_for_sale_response(response_json):
    """
    Process the list for sale API response.

    Convert each listing to a dataframe, append to a list, and concatenate to one dataframe.

    Parameters
    ----------
    @response_json [dictionary]: API response for list for sale

    Returns
    -------
    [dataframe] Dataframe of all list for sale responses

    """

    # empty dataframe
    dataframe_list = []

    # iterate through each for sale listing
    for j in range(len(response_json)):
        #response_json[j]['listing']['propertyDetails'].pop('features')
        k = response_json[j]['listing']['propertyDetails'].copy()
        k['id']  = response_json[j]['listing']['id']
        print(k)
        # convert each listing to dataframe 
        _temp_df = pd.DataFrame.from_dict(k, orient='index').T

        # append to dataframe list for all listings
        dataframe_list.append(_temp_df)
    
        # concatenate all dataframes, for missing col values enter null value
    return pd.concat(dataframe_list, axis=0, ignore_index=True, sort=False)

# %%
# setup
property_id="2016858650"
starting_max_price=100000
increment=50000
# when starting min price is zero we'll just use the lower bound plus 400k later on
starting_min_price=0

# %%
# POST request for token
client_id, client_secret = get_api_key(api_key_id="Domain")
response = requests.post('https://auth.domain.com.au/v1/connect/token', data = {'client_id':client_id,"client_secret":client_secret,"grant_type":"client_credentials","scope":"api_listings_read","Content-Type":"text/json"})
token=response.json()
access_token=token["access_token"]

# %%
#domain_api_key = get_api_key(api_key_id = "Domain")
# GET Request for ID
url = "https://api.domain.com.au/v1/listings/"+property_id
auth = {"Authorization":"Bearer "+access_token}
request = requests.get(url,headers=auth)
r=request.json()

# %%
#get details
da=r['addressParts']
postcode=da['postcode']
suburb=da['suburb']
bathrooms=r['bathrooms']
bedrooms=r['bedrooms']
carspaces=r['carspaces']
property_type=r['propertyTypes']
area=r['landAreaSqm']
geolocation=r['geoLocation']

print(property_type, postcode, suburb, bedrooms, bathrooms,  carspaces, area, geolocation)

# the below puts all relevant property types into a single string. eg. a property listing can be a 'house' and a 'townhouse'
n=0
property_type_str=""
for p in r['propertyTypes']:
  property_type_str=property_type_str+(r['propertyTypes'][int(n)])
  n=n+1
print(property_type_str)
# Out:
# ['house'] 2641 Lavington 4 2 2 711 {'latitude': -36.0284049, 'longitude': 146.94486}
# house

# %%
property_list_for_sale_response = api_property_list_for_sale(auth, property_type, bedrooms, bathrooms, suburb, postcode)
property_list_for_sale_response[:5]
# Out:
# [{'type': 'PropertyListing',
#   'listing': {'listingType': 'Sale',
#    'id': 2017722086,
#    'advertiser': {'type': 'Agency',
#     'id': 11909,
#     'name': 'Wood Real Estate',
#     'logoUrl': 'https://images.domain.com.au/img/Agencys/11909/logo_11909.jpeg',
#     'preferredColourHex': '#00197e',
#     'bannerUrl': 'https://images.domain.com.au/img/Agencys/11909/banner_11909.jpeg',
#     'contacts': [{'name': 'Greg Wood',
#       'photoUrl': 'https://images.domain.com.au/img/11909/contact_1577278.jpeg?mod=220411-174032'}]},
#    'priceDetails': {'displayPrice': 'Guide: $579,000 to $599,000'},
#    'media': [{'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017722086_1_1_220407_024056-w1200-h800'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017722086_2_1_220407_024056-w1200-h800'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017722086_3_1_220407_024056-w1200-h800'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017722086_4_1_220407_024056-w1200-h800'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017722086_5_1_220407_024056-w1200-h800'}],
#    'propertyDetails': {'state': 'NSW',
#     'features': ['BuiltInWardrobes',
#      'SecureParking',
#      'Heating',
#      'Dishwasher',
#      'FullyFenced'],
#     'propertyType': 'House',
#     'allPropertyTypes': ['House'],
#     'bathrooms': 2.0,
#     'bedrooms': 4.0,
#     'carspaces': 2,
#     'unitNumber': '',
#     'streetNumber': '281',
#     'street': 'Highview Cres',
#     'area': 'Albury - Greater Region',
#     'region': 'Regional NSW',
#     'suburb': 'LAVINGTON',
#     'postcode': '2641',
#     'displayableAddress': '281 Highview Cres, Lavington',
#     'latitude': -36.0469856,
#     'longitude': 146.952911,
#     'isRural': False,
#     'isNew': False,
#     'tags': []},
#    'headline': 'QUICKS HILL - $Million Views',
#    'summaryDescription': '<b></b><br />Imagine waking up to this spectacular view each morning, then to arrive home to the beautiful sunsets each evening. \n\nThis brick rendered, 4-bedroom, double storey home offers the astute purchaser options for separate accommodation downsta...',
#    'hasFloorplan': True,
#    'hasVideo': True,
#    'labels': ['Under offer', 'New'],
#    'dateListed': '2022-04-07T12:41:02',
#    'inspectionSchedule': {'byAppointment': True,
#     'recurring': False,
#     'times': []},
#    'listingSlug': '281-highview-cres-lavington-nsw-2641-2017722086'}},
#  {'type': 'PropertyListing',
#   'listing': {'listingType': 'Sale',
#    'id': 2017713724,
#    'advertiser': {'type': 'Agency',
#     'id': 11794,
#     'name': 'Kane Real Estate',
#     'logoUrl': 'https://images.domain.com.au/img/Agencys/11794/logo_11794.png?date=131871808686873027',
#     'preferredColourHex': '#F2141C',
#     'bannerUrl': 'https://images.domain.com.au/img/Agencys/11794/banner_11794.png?date=131871809106079896',
#     'contacts': [{'name': 'Andrew Kane',
#       'photoUrl': 'https://images.domain.com.au/img/11794/contact_730731.jpeg?mod=220411-090433'},
#      {'name': 'Cameron Brooks',
#       'photoUrl': 'https://images.domain.com.au/img/11794/contact_1799784.jpeg?mod=220411-090433'}]},
#    'priceDetails': {'displayPrice': 'UNDER OFFER'},
#    'media': [{'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017713724_4_1_220405_122642-w2738-h1825'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017713724_3_1_220405_122642-w2738-h1825'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017713724_1_1_220405_122642-w2738-h1825'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017713724_2_1_220405_122642-w2738-h1825'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017713724_5_1_220405_122642-w2738-h1826'}],
#    'propertyDetails': {'state': 'NSW',
#     'features': ['AirConditioning',
#      'Ensuite',
#      'Gas',
#      'SecureParking',
#      'SwimmingPool',
#      'Heating',
#      'Study'],
#     'propertyType': 'House',
#     'allPropertyTypes': ['House'],
#     'bathrooms': 2.0,
#     'bedrooms': 4.0,
#     'carspaces': 4,
#     'unitNumber': '',
#     'streetNumber': '24',
#     'street': 'Keatinge Court',
#     'area': 'Albury - Greater Region',
#     'region': 'Regional NSW',
#     'suburb': 'LAVINGTON',
#     'postcode': '2641',
#     'displayableAddress': '24 Keatinge Court, Lavington',
#     'latitude': -36.0374947,
#     'longitude': 146.955,
#     'landArea': 1280.0,
#     'isRural': False,
#     'isNew': False,
#     'tags': []},
#    'headline': 'Unique Property in a Quiet Court',
#    'summaryDescription': "<b></b><br />At 24 Keatinge Court, you will find a stunning piece of real estate that offers a lifestyle many can only dream about. Situated in one of Lavington's sought-after courts, on a spacious allotment of 1,280m2 (approx.), the property includes ...",
#    'hasFloorplan': True,
#    'hasVideo': False,
#    'labels': ['Under offer', 'New'],
#    'dateListed': '2022-04-05T10:26:44',
#    'inspectionSchedule': {'byAppointment': True,
#     'recurring': False,
#     'times': []},
#    'listingSlug': '24-keatinge-court-lavington-nsw-2641-2017713724'}},
#  {'type': 'PropertyListing',
#   'listing': {'listingType': 'Sale',
#    'id': 2017675509,
#    'advertiser': {'type': 'Agency',
#     'id': 19390,
#     'name': 'Brian Phegan Real Estate',
#     'logoUrl': 'https://images.domain.com.au/img/Agencys/19390/logo_19390.GIF',
#     'preferredColourHex': '#343530',
#     'bannerUrl': 'https://images.domain.com.au/img/Agencys/19390/banner_19390.GIF',
#     'contacts': [{'name': 'Brian Phegan',
#       'photoUrl': 'https://images.domain.com.au/img/19390/contact_984730.JPG?mod=220325-181035'}]},
#    'priceDetails': {'displayPrice': '$420,000'},
#    'media': [{'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017675509_1_1_220318_103225-w1732-h1154'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017675509_2_1_220318_103225-w1732-h1155'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017675509_3_1_220318_103225-w1732-h1155'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017675509_4_1_220318_103225-w1732-h1155'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017675509_5_1_220318_103225-w1732-h1155'}],
#    'propertyDetails': {'state': 'NSW',
#     'features': ['AirConditioning',
#      'BuiltInWardrobes',
#      'Gas',
#      'SecureParking',
#      'NorthFacing',
#      'Heating',
#      'Dishwasher'],
#     'propertyType': 'House',
#     'allPropertyTypes': ['House'],
#     'bathrooms': 1.0,
#     'bedrooms': 3.0,
#     'carspaces': 3,
#     'unitNumber': '',
#     'streetNumber': '434',
#     'street': 'Strang Place',
#     'area': 'Albury - Greater Region',
#     'region': 'Regional NSW',
#     'suburb': 'LAVINGTON',
#     'postcode': '2641',
#     'displayableAddress': '434 Strang Place, Lavington',
#     'latitude': -36.04383,
#     'longitude': 146.937073,
#     'isRural': False,
#     'isNew': False,
#     'tags': []},
#    'headline': 'A Quality Home in a top Location',
#    'summaryDescription': '<b></b><br />Features three good size bedrooms with BIR. Spacious floor plan. Sparkling bathroom. Modern kitchen meals area with laminated cabinetry, electric stove, pantry, bench top work space dishwasher, lots of draws, beautiful floating floor. Dini...',
#    'hasFloorplan': True,
#    'hasVideo': False,
#    'labels': ['New'],
#    'dateListed': '2022-03-18T21:32:26',
#    'inspectionSchedule': {'byAppointment': True,
#     'recurring': False,
#     'times': []},
#    'listingSlug': '434-strang-place-lavington-nsw-2641-2017675509'}},
#  {'type': 'PropertyListing',
#   'listing': {'listingType': 'Sale',
#    'id': 2017726946,
#    'advertiser': {'type': 'Agency',
#     'id': 11839,
#     'name': 'Professionals Wodonga',
#     'logoUrl': 'https://images.domain.com.au/img/Agencys/11839/logo_11839.jpg?date=131991714453343012',
#     'preferredColourHex': '#be0a25',
#     'bannerUrl': 'https://images.domain.com.au/img/Agencys/11839/banner_11839.jpg?date=131991715261154002',
#     'contacts': [{'name': 'Josh Hill',
#       'photoUrl': 'https://images.domain.com.au/img/11839/contact_1478143.jpeg?mod=220420-162231'}]},
#    'priceDetails': {'displayPrice': 'For Sale via Expressions of Interest'},
#    'media': [{'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017726946_1_1_220408_065829-w1500-h1000'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017726946_2_1_220408_065829-w1500-h1000'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017726946_3_1_220408_065829-w1500-h1000'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017726946_4_1_220408_065829-w1500-h1000'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017726946_5_1_220408_065829-w1500-h1000'}],
#    'propertyDetails': {'state': 'NSW',
#     'features': ['Gas',
#      'PetsAllowed',
#      'SecureParking',
#      'Heating',
#      'Dishwasher',
#      'Study',
#      'FullyFenced'],
#     'propertyType': 'House',
#     'allPropertyTypes': ['House'],
#     'bathrooms': 1.0,
#     'bedrooms': 3.0,
#     'carspaces': 2,
#     'unitNumber': '',
#     'streetNumber': '518',
#     'street': 'Marshall Street',
#     'area': 'Albury - Greater Region',
#     'region': 'Regional NSW',
#     'suburb': 'LAVINGTON',
#     'postcode': '2641',
#     'displayableAddress': '518 Marshall Street, Lavington',
#     'latitude': -36.04464,
#     'longitude': 146.9326,
#     'isRural': False,
#     'isNew': False,
#     'tags': []},
#    'headline': 'FEATURE PACKED HOME IN CONVENIENT LOCALE!',
#    'summaryDescription': '<b></b><br />Perfectly positioned on a large 778m2 allotment within proximity of schools and shopping centres, this feature packed home is sure to tick all the boxes.\n\nOffering lovely street appeal, you will be impressed from the moment you arrive, wit...',
#    'hasFloorplan': True,
#    'hasVideo': False,
#    'labels': [],
#    'dateListed': '2022-04-08T16:58:32',
#    'inspectionSchedule': {'byAppointment': False,
#     'recurring': False,
#     'times': [{'openingTime': '2022-04-23T11:00:00',
#       'closingTime': '2022-04-23T11:30:00'}]},
#    'listingSlug': '518-marshall-street-lavington-nsw-2641-2017726946'}},
#  {'type': 'PropertyListing',
#   'listing': {'listingType': 'Sale',
#    'id': 2017684515,
#    'advertiser': {'type': 'Agency',
#     'id': 11631,
#     'name': 'Stean Nicholls Real Estate',
#     'logoUrl': 'https://images.domain.com.au/img/Agencys/11631/logo_11631.GIF',
#     'preferredColourHex': '#000033',
#     'bannerUrl': 'https://images.domain.com.au/img/Agencys/11631/banner_11631.GIF',
#     'contacts': [{'name': 'Nicholas Clark',
#       'photoUrl': 'https://images.domain.com.au/img/11631/contact_1193890.jpeg?mod=220401-161136'},
#      {'name': 'Monique Monahan',
#       'photoUrl': 'https://images.domain.com.au/img/11631/contact_1847751.jpeg?mod=220401-161136'}]},
#    'priceDetails': {'displayPrice': 'Contact Agent'},
#    'media': [{'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017684515_1_1_220323_052055-w4000-h2667'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017684515_2_1_220323_052055-w4000-h2247'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017684515_3_1_220323_052055-w4000-h2247'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017684515_4_1_220323_052055-w4000-h2667'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017684515_5_1_220323_052055-w4000-h2667'}],
#    'propertyDetails': {'state': 'NSW',
#     'features': ['AirConditioning',
#      'Ensuite',
#      'Gas',
#      'SwimmingPool',
#      'Heating',
#      'Shed'],
#     'propertyType': 'House',
#     'allPropertyTypes': ['House'],
#     'bathrooms': 2.0,
#     'bedrooms': 4.0,
#     'carspaces': 2,
#     'unitNumber': '',
#     'streetNumber': '306',
#     'street': 'Sutherland Street',
#     'area': 'Albury - Greater Region',
#     'region': 'Regional NSW',
#     'suburb': 'LAVINGTON',
#     'postcode': '2641',
#     'displayableAddress': '306 Sutherland Street, Lavington',
#     'latitude': -36.0541763,
#     'longitude': 146.949036,
#     'landArea': 942.0,
#     'isRural': False,
#     'isNew': False,
#     'tags': []},
#    'headline': 'Massive Space For The Whole Family',
#    'summaryDescription': '<b></b><br />Extended to provide massive living spaces and a flexible floor plan, 306 Sutherland Street packs plenty of value to those seeking room to move.\n\nSpread over a single level, the home offers a formal lounge at the front, complemented by thre...',
#    'hasFloorplan': True,
#    'hasVideo': False,
#    'labels': [],
#    'dateListed': '2022-03-23T16:21:00',
#    'inspectionSchedule': {'byAppointment': False,
#     'recurring': False,
#     'times': []},
#    'listingSlug': '306-sutherland-street-lavington-nsw-2641-2017684515'}}]

# %%
df_properties_for_sale_raw = process_list_for_sale_response(response_json=property_list_for_sale_response)

df_properties_for_sale_raw
# Out:
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'SecureParking', 'Heating', 'Dishwasher', 'FullyFenced'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '281', 'street': 'Highview Cres', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '281 Highview Cres, Lavington', 'latitude': -36.0469856, 'longitude': 146.952911, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017722086}
# {'state': 'NSW', 'features': ['AirConditioning', 'Ensuite', 'Gas', 'SecureParking', 'SwimmingPool', 'Heating', 'Study'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'carspaces': 4, 'unitNumber': '', 'streetNumber': '24', 'street': 'Keatinge Court', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '24 Keatinge Court, Lavington', 'latitude': -36.0374947, 'longitude': 146.955, 'landArea': 1280.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017713724}
# {'state': 'NSW', 'features': ['AirConditioning', 'BuiltInWardrobes', 'Gas', 'SecureParking', 'NorthFacing', 'Heating', 'Dishwasher'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 3, 'unitNumber': '', 'streetNumber': '434', 'street': 'Strang Place', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '434 Strang Place, Lavington', 'latitude': -36.04383, 'longitude': 146.937073, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017675509}
# {'state': 'NSW', 'features': ['Gas', 'PetsAllowed', 'SecureParking', 'Heating', 'Dishwasher', 'Study', 'FullyFenced'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '518', 'street': 'Marshall Street', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '518 Marshall Street, Lavington', 'latitude': -36.04464, 'longitude': 146.9326, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017726946}
# {'state': 'NSW', 'features': ['AirConditioning', 'Ensuite', 'Gas', 'SwimmingPool', 'Heating', 'Shed'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '306', 'street': 'Sutherland Street', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '306 Sutherland Street, Lavington', 'latitude': -36.0541763, 'longitude': 146.949036, 'landArea': 942.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017684515}
# {'state': 'NSW', 'features': ['Ensuite', 'Gas', 'SecureParking', 'Heating', 'RainwaterStorageTank'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '32', 'street': 'Mulberry Court', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '32 Mulberry Court, Lavington', 'latitude': -36.0552368, 'longitude': 146.958618, 'landArea': 1223.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017664350}
# {'state': 'NSW', 'features': ['Gas', 'SecureParking', 'SwimmingPool', 'Shed'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 6, 'unitNumber': '', 'streetNumber': '443', 'street': 'Romani Drive', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '443 Romani Drive, Lavington', 'latitude': -36.037426, 'longitude': 146.941742, 'landArea': 785.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017659425}
# {'state': 'NSW', 'features': ['Ensuite', 'Floorboards', 'Heating', 'Dishwasher', 'Shed'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'unitNumber': '', 'streetNumber': '314', 'street': 'Mark Crescent', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '314 Mark Crescent, Lavington', 'latitude': -36.04677, 'longitude': 146.948776, 'landArea': 858.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017715734}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'Ensuite', 'SecureParking', 'SwimmingPool', 'Heating', 'Dishwasher'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 3.0, 'bedrooms': 5.0, 'carspaces': 6, 'unitNumber': '', 'streetNumber': '330', 'street': 'Christopher Court', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '330 Christopher Court, Lavington', 'latitude': -36.0524445, 'longitude': 146.947281, 'landArea': 1206.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017675131}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'Gas', 'Dishwasher', 'Study'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 4, 'unitNumber': '', 'streetNumber': '30', 'street': 'Julie Place', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '30 Julie Place, Lavington', 'latitude': -36.04731, 'longitude': 146.94635, 'landArea': 839.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017665995}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'Gas', 'SwimmingPool', 'Heating', 'Shed'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 2, 'unitNumber': '32', 'streetNumber': '7', 'street': 'Catherine Crescent', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '32/7 Catherine Crescent, Lavington', 'latitude': -36.0419579, 'longitude': 146.958038, 'isRural': False, 'isNew': False, 'tags': ['retirement property'], 'id': 2017729044}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'Ensuite', 'Gas', 'SecureParking'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'carspaces': 5, 'unitNumber': '', 'streetNumber': '479', 'street': 'Laramee Drive', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '479 Laramee Drive, Lavington', 'latitude': -36.0403938, 'longitude': 146.944473, 'landArea': 669.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017723897}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'SwimmingPool', 'Study', 'Shed'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 2.0, 'carspaces': 2, 'unitNumber': '20', 'streetNumber': '7', 'street': 'Catherine Crescent', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '20/7 Catherine Crescent, Lavington', 'latitude': -36.0419579, 'longitude': 146.958038, 'isRural': False, 'isNew': False, 'tags': ['retirement property'], 'id': 2017695000}
# {'state': 'NSW', 'features': [], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 1, 'unitNumber': '', 'streetNumber': '455', 'street': 'Danes Street', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '455 Danes Street, Lavington', 'latitude': -36.0422325, 'longitude': 146.935715, 'landArea': 847.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017680738}
# {'state': 'NSW', 'features': ['Bath', 'Heating', 'Shed'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 4.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '302', 'street': 'Highview Crescent', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '302 Highview Crescent, Lavington', 'latitude': -36.0455627, 'longitude': 146.95137, 'landArea': 822.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017564090}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'Heating', 'Dishwasher', 'Shed', 'FullyFenced'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 4, 'unitNumber': '', 'streetNumber': '657', 'street': 'Briardale Rd', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '657 Briardale Rd, Lavington', 'latitude': -36.0451775, 'longitude': 146.920639, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017544087}
# {'state': 'NSW', 'features': ['Gas', 'SecureParking', 'Heating', 'Dishwasher'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '403', 'street': 'Carlma Crescent', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '403 Carlma Crescent, Lavington', 'latitude': -36.04733, 'longitude': 146.951736, 'landArea': 774.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017534283}
# {'state': 'NSW', 'features': ['AirConditioning', 'BuiltInWardrobes', 'Floorboards', 'SecureParking', 'Bath', 'Heating', 'Dishwasher', 'FullyFenced'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 4.0, 'carspaces': 3, 'unitNumber': '', 'streetNumber': '499', 'street': 'Alldis Avenue', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '499 Alldis Avenue, Lavington', 'latitude': -36.0389137, 'longitude': 146.933716, 'landArea': 1236.0, 'buildingArea': 140.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017493162}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'CableOrSatellite', 'Ensuite', 'Floorboards', 'Gas', 'SecureParking', 'Heating', 'Dishwasher', 'Study', 'FullyFenced', 'SolarPanels'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 3.0, 'bedrooms': 6.0, 'carspaces': 7, 'unitNumber': '1 & 2', 'streetNumber': '475', 'street': 'HENDERSON STREET', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '1 & 2/475 HENDERSON STREET, Lavington', 'latitude': -36.04682, 'longitude': 146.935913, 'landArea': 1026.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017491893}
# {'state': 'NSW', 'features': ['AirConditioning', 'BuiltInWardrobes', 'Gas', 'Heating'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 1, 'unitNumber': '', 'streetNumber': '402', 'street': 'Kaylock Road', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '402 Kaylock Road, Lavington', 'latitude': -36.0496674, 'longitude': 146.941757, 'landArea': 363.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017490921}
# {'state': 'NSW', 'features': ['Bath', 'Dishwasher', 'Study'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 1, 'unitNumber': '', 'streetNumber': '333', 'street': 'Haines Court', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '333 Haines Court, Lavington', 'latitude': -36.05361, 'longitude': 146.946884, 'landArea': 670.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017742077}
# {'state': 'NSW', 'features': ['Ensuite', 'SecureParking', 'Shed', 'SolarPanels'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 3.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '3', 'street': 'Owen Court', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '3 Owen Court, Lavington', 'latitude': -36.03504, 'longitude': 146.952713, 'landArea': 1097.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017702697}
# {'state': 'NSW', 'features': ['SecureParking'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 4.0, 'carspaces': 4, 'unitNumber': '', 'streetNumber': '282', 'street': 'Clarence Street', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '282 Clarence Street, Lavington', 'latitude': -36.0535469, 'longitude': 146.951462, 'landArea': 1425.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017699151}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'SecureParking', 'Heating', 'FullyFenced'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 3.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '268', 'street': 'Highview Crescent', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '268 Highview Crescent, Lavington', 'latitude': -36.0474777, 'longitude': 146.953949, 'landArea': 923.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017673449}
# {'state': 'NSW', 'features': ['Ensuite', 'SecureParking', 'SwimmingPool', 'Heating', 'Study', 'Shed'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '60', 'street': 'Mountain View Drive', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '60 Mountain View Drive, Lavington', 'latitude': -36.0486, 'longitude': 146.955551, 'landArea': 803.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017665024}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'CableOrSatellite', 'Ensuite', 'SecureParking', 'SwimmingPool', 'Heating', 'Dishwasher', 'Shed', 'FullyFenced', 'SolarPanels'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '504', 'street': 'Urana Road', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '504 Urana Road, Lavington', 'latitude': -36.03743, 'longitude': 146.926086, 'landArea': 1031.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017658507}
# {'state': 'NSW', 'features': ['SwimmingPool', 'Heating', 'Dishwasher', 'Shed'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 2.0, 'carspaces': 1, 'unitNumber': '40', 'streetNumber': '7', 'street': 'Catherine Crescent', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '40/7 Catherine Crescent, Lavington', 'latitude': -36.0419579, 'longitude': 146.958038, 'isRural': False, 'isNew': False, 'tags': ['retirement property'], 'id': 2017592721}
# {'state': 'NSW', 'features': ['Ensuite', 'Gas', 'SecureParking', 'Heating', 'SolarPanels'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 2.0, 'bedrooms': 4.0, 'carspaces': 2, 'unitNumber': '', 'streetNumber': '5', 'street': 'Worsley Place', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '5 Worsley Place, Lavington', 'latitude': -36.0337677, 'longitude': 146.938553, 'landArea': 720.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017579423}
# {'state': 'NSW', 'features': ['Gas', 'Heating', 'Shed'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 1.0, 'bedrooms': 3.0, 'carspaces': 1, 'unitNumber': '', 'streetNumber': '407', 'street': 'Parnall Street', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '407 Parnall Street, Lavington', 'latitude': -36.04491, 'longitude': 146.930664, 'landArea': 1011.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017745452}
# {'state': 'NSW', 'features': ['BuiltInWardrobes', 'Ensuite', 'Floorboards', 'Gas', 'SwimmingPool', 'Bath', 'Heating', 'Dishwasher', 'Study', 'RainwaterStorageTank', 'SolarPanels'], 'propertyType': 'House', 'allPropertyTypes': ['House'], 'bathrooms': 3.0, 'bedrooms': 4.0, 'carspaces': 5, 'unitNumber': '', 'streetNumber': '39', 'street': 'Michelle Avenue', 'area': 'Albury - Greater Region', 'region': 'Regional NSW', 'suburb': 'LAVINGTON', 'postcode': '2641', 'displayableAddress': '39 Michelle Avenue, Lavington', 'latitude': -36.0420837, 'longitude': 146.921844, 'landArea': 637.0, 'isRural': False, 'isNew': False, 'tags': [], 'id': 2017665768}
#    state                                           features propertyType  \
# 0    NSW  [BuiltInWardrobes, SecureParking, Heating, Dis...        House
# 1    NSW  [AirConditioning, Ensuite, Gas, SecureParking,...        House
# 2    NSW  [AirConditioning, BuiltInWardrobes, Gas, Secur...        House
# 3    NSW  [Gas, PetsAllowed, SecureParking, Heating, Dis...        House
# 4    NSW  [AirConditioning, Ensuite, Gas, SwimmingPool, ...        House
# 5    NSW  [Ensuite, Gas, SecureParking, Heating, Rainwat...        House
# 6    NSW           [Gas, SecureParking, SwimmingPool, Shed]        House
# 7    NSW  [Ensuite, Floorboards, Heating, Dishwasher, Shed]        House
# 8    NSW  [BuiltInWardrobes, Ensuite, SecureParking, Swi...        House
# 9    NSW         [BuiltInWardrobes, Gas, Dishwasher, Study]        House
# 10   NSW  [BuiltInWardrobes, Gas, SwimmingPool, Heating,...        House
# 11   NSW    [BuiltInWardrobes, Ensuite, Gas, SecureParking]        House
# 12   NSW      [BuiltInWardrobes, SwimmingPool, Study, Shed]        House
# 13   NSW                                                 []        House
# 14   NSW                              [Bath, Heating, Shed]        House
# 15   NSW  [BuiltInWardrobes, Heating, Dishwasher, Shed, ...        House
# 16   NSW          [Gas, SecureParking, Heating, Dishwasher]        House
# 17   NSW  [AirConditioning, BuiltInWardrobes, Floorboard...        House
# 18   NSW  [BuiltInWardrobes, CableOrSatellite, Ensuite, ...        House
# 19   NSW  [AirConditioning, BuiltInWardrobes, Gas, Heating]        House
# 20   NSW                          [Bath, Dishwasher, Study]        House
# 21   NSW        [Ensuite, SecureParking, Shed, SolarPanels]        House
# 22   NSW                                    [SecureParking]        House
# 23   NSW  [BuiltInWardrobes, SecureParking, Heating, Ful...        House
# 24   NSW  [Ensuite, SecureParking, SwimmingPool, Heating...        House
# 25   NSW  [BuiltInWardrobes, CableOrSatellite, Ensuite, ...        House
# 26   NSW          [SwimmingPool, Heating, Dishwasher, Shed]        House
# 27   NSW  [Ensuite, Gas, SecureParking, Heating, SolarPa...        House
# 28   NSW                               [Gas, Heating, Shed]        House
# 29   NSW  [BuiltInWardrobes, Ensuite, Floorboards, Gas, ...        House
#
#    allPropertyTypes bathrooms bedrooms carspaces unitNumber streetNumber  \
# 0           [House]       2.0      4.0         2                     281
# 1           [House]       2.0      4.0         4                      24
# 2           [House]       1.0      3.0         3                     434
# 3           [House]       1.0      3.0         2                     518
# 4           [House]       2.0      4.0         2                     306
# 5           [House]       2.0      4.0         2                      32
# 6           [House]       1.0      3.0         6                     443
# 7           [House]       2.0      4.0       NaN                     314
# 8           [House]       3.0      5.0         6                     330
# 9           [House]       1.0      3.0         4                      30
# 10          [House]       1.0      3.0         2         32            7
# 11          [House]       2.0      4.0         5                     479
# 12          [House]       1.0      2.0         2         20            7
# 13          [House]       1.0      3.0         1                     455
# 14          [House]       1.0      4.0         2                     302
# 15          [House]       1.0      3.0         4                     657
# 16          [House]       2.0      4.0         2                     403
# 17          [House]       1.0      4.0         3                     499
# 18          [House]       3.0      6.0         7      1 & 2          475
# 19          [House]       1.0      3.0         1                     402
# 20          [House]       1.0      3.0         1                     333
# 21          [House]       2.0      3.0         2                       3
# 22          [House]       1.0      4.0         4                     282
# 23          [House]       2.0      3.0         2                     268
# 24          [House]       2.0      4.0         2                      60
# 25          [House]       2.0      4.0         2                     504
# 26          [House]       1.0      2.0         1         40            7
# 27          [House]       2.0      4.0         2                       5
# 28          [House]       1.0      3.0         1                     407
# 29          [House]       3.0      4.0         5                      39
#
#                  street                     area        region     suburb  \
# 0         Highview Cres  Albury - Greater Region  Regional NSW  LAVINGTON
# 1        Keatinge Court  Albury - Greater Region  Regional NSW  LAVINGTON
# 2          Strang Place  Albury - Greater Region  Regional NSW  LAVINGTON
# 3       Marshall Street  Albury - Greater Region  Regional NSW  LAVINGTON
# 4     Sutherland Street  Albury - Greater Region  Regional NSW  LAVINGTON
# 5        Mulberry Court  Albury - Greater Region  Regional NSW  LAVINGTON
# 6          Romani Drive  Albury - Greater Region  Regional NSW  LAVINGTON
# 7         Mark Crescent  Albury - Greater Region  Regional NSW  LAVINGTON
# 8     Christopher Court  Albury - Greater Region  Regional NSW  LAVINGTON
# 9           Julie Place  Albury - Greater Region  Regional NSW  LAVINGTON
# 10   Catherine Crescent  Albury - Greater Region  Regional NSW  LAVINGTON
# 11        Laramee Drive  Albury - Greater Region  Regional NSW  LAVINGTON
# 12   Catherine Crescent  Albury - Greater Region  Regional NSW  LAVINGTON
# 13         Danes Street  Albury - Greater Region  Regional NSW  LAVINGTON
# 14    Highview Crescent  Albury - Greater Region  Regional NSW  LAVINGTON
# 15         Briardale Rd  Albury - Greater Region  Regional NSW  LAVINGTON
# 16      Carlma Crescent  Albury - Greater Region  Regional NSW  LAVINGTON
# 17        Alldis Avenue  Albury - Greater Region  Regional NSW  LAVINGTON
# 18     HENDERSON STREET  Albury - Greater Region  Regional NSW  LAVINGTON
# 19         Kaylock Road  Albury - Greater Region  Regional NSW  LAVINGTON
# 20         Haines Court  Albury - Greater Region  Regional NSW  LAVINGTON
# 21           Owen Court  Albury - Greater Region  Regional NSW  LAVINGTON
# 22      Clarence Street  Albury - Greater Region  Regional NSW  LAVINGTON
# 23    Highview Crescent  Albury - Greater Region  Regional NSW  LAVINGTON
# 24  Mountain View Drive  Albury - Greater Region  Regional NSW  LAVINGTON
# 25           Urana Road  Albury - Greater Region  Regional NSW  LAVINGTON
# 26   Catherine Crescent  Albury - Greater Region  Regional NSW  LAVINGTON
# 27        Worsley Place  Albury - Greater Region  Regional NSW  LAVINGTON
# 28       Parnall Street  Albury - Greater Region  Regional NSW  LAVINGTON
# 29      Michelle Avenue  Albury - Greater Region  Regional NSW  LAVINGTON
#
#    postcode                     displayableAddress   latitude   longitude  \
# 0      2641           281 Highview Cres, Lavington -36.046986  146.952911
# 1      2641           24 Keatinge Court, Lavington -36.037495     146.955
# 2      2641            434 Strang Place, Lavington  -36.04383  146.937073
# 3      2641         518 Marshall Street, Lavington  -36.04464    146.9326
# 4      2641       306 Sutherland Street, Lavington -36.054176  146.949036
# 5      2641           32 Mulberry Court, Lavington -36.055237  146.958618
# 6      2641            443 Romani Drive, Lavington -36.037426  146.941742
# 7      2641           314 Mark Crescent, Lavington  -36.04677  146.948776
# 8      2641       330 Christopher Court, Lavington -36.052445  146.947281
# 9      2641              30 Julie Place, Lavington  -36.04731   146.94635
# 10     2641     32/7 Catherine Crescent, Lavington -36.041958  146.958038
# 11     2641           479 Laramee Drive, Lavington -36.040394  146.944473
# 12     2641     20/7 Catherine Crescent, Lavington -36.041958  146.958038
# 13     2641            455 Danes Street, Lavington -36.042232  146.935715
# 14     2641       302 Highview Crescent, Lavington -36.045563   146.95137
# 15     2641            657 Briardale Rd, Lavington -36.045178  146.920639
# 16     2641         403 Carlma Crescent, Lavington  -36.04733  146.951736
# 17     2641           499 Alldis Avenue, Lavington -36.038914  146.933716
# 18     2641  1 & 2/475 HENDERSON STREET, Lavington  -36.04682  146.935913
# 19     2641            402 Kaylock Road, Lavington -36.049667  146.941757
# 20     2641            333 Haines Court, Lavington  -36.05361  146.946884
# 21     2641                3 Owen Court, Lavington  -36.03504  146.952713
# 22     2641         282 Clarence Street, Lavington -36.053547  146.951462
# 23     2641       268 Highview Crescent, Lavington -36.047478  146.953949
# 24     2641      60 Mountain View Drive, Lavington   -36.0486  146.955551
# 25     2641              504 Urana Road, Lavington  -36.03743  146.926086
# 26     2641     40/7 Catherine Crescent, Lavington -36.041958  146.958038
# 27     2641             5 Worsley Place, Lavington -36.033768  146.938553
# 28     2641          407 Parnall Street, Lavington  -36.04491  146.930664
# 29     2641          39 Michelle Avenue, Lavington -36.042084  146.921844
#
#    isRural  isNew                   tags          id landArea buildingArea
# 0    False  False                     []  2017722086      NaN          NaN
# 1    False  False                     []  2017713724   1280.0          NaN
# 2    False  False                     []  2017675509      NaN          NaN
# 3    False  False                     []  2017726946      NaN          NaN
# 4    False  False                     []  2017684515    942.0          NaN
# 5    False  False                     []  2017664350   1223.0          NaN
# 6    False  False                     []  2017659425    785.0          NaN
# 7    False  False                     []  2017715734    858.0          NaN
# 8    False  False                     []  2017675131   1206.0          NaN
# 9    False  False                     []  2017665995    839.0          NaN
# 10   False  False  [retirement property]  2017729044      NaN          NaN
# 11   False  False                     []  2017723897    669.0          NaN
# 12   False  False  [retirement property]  2017695000      NaN          NaN
# 13   False  False                     []  2017680738    847.0          NaN
# 14   False  False                     []  2017564090    822.0          NaN
# 15   False  False                     []  2017544087      NaN          NaN
# 16   False  False                     []  2017534283    774.0          NaN
# 17   False  False                     []  2017493162   1236.0        140.0
# 18   False  False                     []  2017491893   1026.0          NaN
# 19   False  False                     []  2017490921    363.0          NaN
# 20   False  False                     []  2017742077    670.0          NaN
# 21   False  False                     []  2017702697   1097.0          NaN
# 22   False  False                     []  2017699151   1425.0          NaN
# 23   False  False                     []  2017673449    923.0          NaN
# 24   False  False                     []  2017665024    803.0          NaN
# 25   False  False                     []  2017658507   1031.0          NaN
# 26   False  False  [retirement property]  2017592721      NaN          NaN
# 27   False  False                     []  2017579423    720.0          NaN
# 28   False  False                     []  2017745452   1011.0          NaN
# 29   False  False                     []  2017665768    637.0          NaN

# %%
def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}"">{}</a>'.format(val, val)

# %%
df_properties_for_sale_raw.shape
# Out:
# (30, 23)

# %%
df_properties_for_sale_raw.to_csv("output/ForSale_Properties.csv", index = False)

# %%
from sklearn.cluster import DBSCAN


df_properties_for_sale_raw["labels"] = DBSCAN(eps=0.01, min_samples=3).fit(df_properties_for_sale_raw[["latitude","longitude"]].values).labels_
df_properties_for_sale_raw = df_properties_for_sale_raw.drop(['allPropertyTypes','buildingArea'], axis = 1)
df_properties_for_sale_raw = df_properties_for_sale_raw.dropna()
df_properties_for_sale_raw.landArea = df_properties_for_sale_raw.landArea.astype(int)
df_properties_for_sale_raw.bathrooms = df_properties_for_sale_raw.bathrooms.astype(int)
df_properties_for_sale_raw.bedrooms = df_properties_for_sale_raw.bedrooms.astype(int)
df_properties_for_sale_raw.carspaces = df_properties_for_sale_raw.carspaces.astype(int)
df_properties_for_sale_raw['URL'] = 'http://www.domain.com.au/' + df_properties_for_sale_raw.id.apply(str)
df_properties_for_sale_raw = df_properties_for_sale_raw.drop(df_properties_for_sale_raw[df_properties_for_sale_raw["landArea"] > 2000].index)
df_properties_for_sale = df_properties_for_sale_raw.style.format({'URL': make_clickable})

# %%
df_properties_for_sale
# Out:
# <style type="text/css">
# </style>
# <table id="T_92238">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92238_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_92238_level0_col1" class="col_heading level0 col1" >features</th>
#       <th id="T_92238_level0_col2" class="col_heading level0 col2" >propertyType</th>
#       <th id="T_92238_level0_col3" class="col_heading level0 col3" >bathrooms</th>
#       <th id="T_92238_level0_col4" class="col_heading level0 col4" >bedrooms</th>
#       <th id="T_92238_level0_col5" class="col_heading level0 col5" >carspaces</th>
#       <th id="T_92238_level0_col6" class="col_heading level0 col6" >unitNumber</th>
#       <th id="T_92238_level0_col7" class="col_heading level0 col7" >streetNumber</th>
#       <th id="T_92238_level0_col8" class="col_heading level0 col8" >street</th>
#       <th id="T_92238_level0_col9" class="col_heading level0 col9" >area</th>
#       <th id="T_92238_level0_col10" class="col_heading level0 col10" >region</th>
#       <th id="T_92238_level0_col11" class="col_heading level0 col11" >suburb</th>
#       <th id="T_92238_level0_col12" class="col_heading level0 col12" >postcode</th>
#       <th id="T_92238_level0_col13" class="col_heading level0 col13" >displayableAddress</th>
#       <th id="T_92238_level0_col14" class="col_heading level0 col14" >latitude</th>
#       <th id="T_92238_level0_col15" class="col_heading level0 col15" >longitude</th>
#       <th id="T_92238_level0_col16" class="col_heading level0 col16" >isRural</th>
#       <th id="T_92238_level0_col17" class="col_heading level0 col17" >isNew</th>
#       <th id="T_92238_level0_col18" class="col_heading level0 col18" >tags</th>
#       <th id="T_92238_level0_col19" class="col_heading level0 col19" >id</th>
#       <th id="T_92238_level0_col20" class="col_heading level0 col20" >landArea</th>
#       <th id="T_92238_level0_col21" class="col_heading level0 col21" >labels</th>
#       <th id="T_92238_level0_col22" class="col_heading level0 col22" >URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92238_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_92238_row0_col0" class="data row0 col0" >NSW</td>
#       <td id="T_92238_row0_col1" class="data row0 col1" >['AirConditioning', 'Ensuite', 'Gas', 'SecureParking', 'SwimmingPool', 'Heating', 'Study']</td>
#       <td id="T_92238_row0_col2" class="data row0 col2" >House</td>
#       <td id="T_92238_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_92238_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_92238_row0_col5" class="data row0 col5" >4</td>
#       <td id="T_92238_row0_col6" class="data row0 col6" ></td>
#       <td id="T_92238_row0_col7" class="data row0 col7" >24</td>
#       <td id="T_92238_row0_col8" class="data row0 col8" >Keatinge Court</td>
#       <td id="T_92238_row0_col9" class="data row0 col9" >Albury - Greater Region</td>
#       <td id="T_92238_row0_col10" class="data row0 col10" >Regional NSW</td>
#       <td id="T_92238_row0_col11" class="data row0 col11" >LAVINGTON</td>
#       <td id="T_92238_row0_col12" class="data row0 col12" >2641</td>
#       <td id="T_92238_row0_col13" class="data row0 col13" >24 Keatinge Court, Lavington</td>
#       <td id="T_92238_row0_col14" class="data row0 col14" >-36.037495</td>
#       <td id="T_92238_row0_col15" class="data row0 col15" >146.955000</td>
#       <td id="T_92238_row0_col16" class="data row0 col16" >False</td>
#       <td id="T_92238_row0_col17" class="data row0 col17" >False</td>
#       <td id="T_92238_row0_col18" class="data row0 col18" >[]</td>
#       <td id="T_92238_row0_col19" class="data row0 col19" >2017713724</td>
#       <td id="T_92238_row0_col20" class="data row0 col20" >1280</td>
#       <td id="T_92238_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_92238_row0_col22" class="data row0 col22" ><a target="_blank" href="http://www.domain.com.au/2017713724"">http://www.domain.com.au/2017713724</a></td>
#     </tr>
#     <tr>
#       <th id="T_92238_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_92238_row1_col0" class="data row1 col0" >NSW</td>
#       <td id="T_92238_row1_col1" class="data row1 col1" >['AirConditioning', 'Ensuite', 'Gas', 'SwimmingPool', 'Heating', 'Shed']</td>
#       <td id="T_92238_row1_col2" class="data row1 col2" >House</td>
#       <td id="T_92238_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_92238_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_92238_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_92238_row1_col6" class="data row1 col6" ></td>
#       <td id="T_92238_row1_col7" class="data row1 col7" >306</td>
#       <td id="T_92238_row1_col8" class="data row1 col8" >Sutherland Street</td>
#       <td id="T_92238_row1_col9" class="data row1 col9" >Albury - Greater Region</td>
#       <td id="T_92238_row1_col10" class="data row1 col10" >Regional NSW</td>
#       <td id="T_92238_row1_col11" class="data row1 col11" >LAVINGTON</td>
#       <td id="T_92238_row1_col12" class="data row1 col12" >2641</td>
#       <td id="T_92238_row1_col13" class="data row1 col13" >306 Sutherland Street, Lavington</td>
#       <td id="T_92238_row1_col14" class="data row1 col14" >-36.054176</td>
#       <td id="T_92238_row1_col15" class="data row1 col15" >146.949036</td>
#       <td id="T_92238_row1_col16" class="data row1 col16" >False</td>
#       <td id="T_92238_row1_col17" class="data row1 col17" >False</td>
#       <td id="T_92238_row1_col18" class="data row1 col18" >[]</td>
#       <td id="T_92238_row1_col19" class="data row1 col19" >2017684515</td>
#       <td id="T_92238_row1_col20" class="data row1 col20" >942</td>
#       <td id="T_92238_row1_col21" class="data row1 col21" >0</td>
#       <td id="T_92238_row1_col22" class="data row1 col22" ><a target="_blank" href="http://www.domain.com.au/2017684515"">http://www.domain.com.au/2017684515</a></td>
#     </tr>
#     <tr>
#       <th id="T_92238_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_92238_row2_col0" class="data row2 col0" >NSW</td>
#       <td id="T_92238_row2_col1" class="data row2 col1" >['Ensuite', 'Gas', 'SecureParking', 'Heating', 'RainwaterStorageTank']</td>
#       <td id="T_92238_row2_col2" class="data row2 col2" >House</td>
#       <td id="T_92238_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_92238_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_92238_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_92238_row2_col6" class="data row2 col6" ></td>
#       <td id="T_92238_row2_col7" class="data row2 col7" >32</td>
#       <td id="T_92238_row2_col8" class="data row2 col8" >Mulberry Court</td>
#       <td id="T_92238_row2_col9" class="data row2 col9" >Albury - Greater Region</td>
#       <td id="T_92238_row2_col10" class="data row2 col10" >Regional NSW</td>
#       <td id="T_92238_row2_col11" class="data row2 col11" >LAVINGTON</td>
#       <td id="T_92238_row2_col12" class="data row2 col12" >2641</td>
#       <td id="T_92238_row2_col13" class="data row2 col13" >32 Mulberry Court, Lavington</td>
#       <td id="T_92238_row2_col14" class="data row2 col14" >-36.055237</td>
#       <td id="T_92238_row2_col15" class="data row2 col15" >146.958618</td>
#       <td id="T_92238_row2_col16" class="data row2 col16" >False</td>
#       <td id="T_92238_row2_col17" class="data row2 col17" >False</td>
#       <td id="T_92238_row2_col18" class="data row2 col18" >[]</td>
#       <td id="T_92238_row2_col19" class="data row2 col19" >2017664350</td>
#       <td id="T_92238_row2_col20" class="data row2 col20" >1223</td>
#       <td id="T_92238_row2_col21" class="data row2 col21" >0</td>
#       <td id="T_92238_row2_col22" class="data row2 col22" ><a target="_blank" href="http://www.domain.com.au/2017664350"">http://www.domain.com.au/2017664350</a></td>
#     </tr>
#     <tr>
#       <th id="T_92238_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_92238_row3_col0" class="data row3 col0" >NSW</td>
#       <td id="T_92238_row3_col1" class="data row3 col1" >['Gas', 'SecureParking', 'SwimmingPool', '

# %%
def search_for_price(data, starting_min_price, starting_max_price, increment):
    
    url = "https://api.domain.com.au/v1/listings/residential/_search" # Set destination URL here

    max_price=starting_max_price

    searching_for_price_l = True
    while searching_for_price_l:
        post_fields ={
        "listingType":"Sale",
            "maxPrice":max_price,
            "pageSize":100,
        "propertyTypes":['house'],
        "minBedrooms":data['bedrooms'],
            "maxBedrooms":data['bedrooms'],
        "minBathrooms":data['bathrooms'],
            "maxBathrooms":data['bathrooms'],
        "locations":[
            {
            "state":"",
            "region":"",
            "area":"",
            "suburb":data['suburb'],
            "postCode":data['postcode'],
            "includeSurroundingSuburbs":False
            }
        ]
        }

        request = requests.post(url,headers=auth,json=post_fields)

        l=request.json()
        listings = []
        for listing in l:
            listings.append(listing["listing"]["id"])
        listings

        if int(property_id) in listings:
                max_price=max_price-increment
                print("Lower bound found: ", max_price)
                searching_for_price_l=False
        else:
            max_price=max_price+increment
            print("Not found. Increasing max price to ",max_price)
            time.sleep(0.1)  # sleep a bit so you don't make too many API calls too quickly )


    if starting_min_price>0:
            min_price=starting_min_price
            
    else:  
            min_price=max_price+400000


    searching_for_price_u = True
    while searching_for_price_u:
        post_fields ={
        "listingType":"Sale",
            "minPrice":min_price,
            "pageSize":100,
        "propertyTypes":['house'],
        "minBedrooms":data['bedrooms'],
            "maxBedrooms":data['bedrooms'],
        "minBathrooms":data['bathrooms'],
            "maxBathrooms":data['bathrooms'],
        "locations":[
            {
            "state":"",
            "region":"",
            "area":"",
            "suburb":data['suburb'],
            "postCode":data['postcode'],
            "includeSurroundingSuburbs":False
            }
        ]
        }

        request = requests.post(url,headers=auth,json=post_fields)

        l=request.json()
        listings = []
        for listing in l:
            listings.append(listing["listing"]["id"])
        listings

        if int(property_id) in listings:
                min_price=min_price+increment
                print("Upper bound found: ", min_price)
                searching_for_price_u=False
        else:
            min_price=min_price-increment
            print("Not found. Decreasing min price to ",min_price)
            time.sleep(0.1)  # sleep a bit so you don't make too many API calls too quickly )

        if max_price<1000000:
            lower=max_price/1000
            upper=min_price/1000
            denom="k"
        else: 
            lower=max_price/1000000
            upper=min_price/1000000
            denom="m"
    

    return print("Price range:","$",lower,"-","$",upper,denom)

# %%
import plotly.express as px

fig = px.scatter_mapbox(df_properties_for_sale_raw, lat="latitude", lon="longitude", size = "landArea", hover_name="URL", hover_data=["propertyType", "bedrooms", "bathrooms", "landArea", "displayableAddress"],zoom=15, height=600)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# # End of Notebook
