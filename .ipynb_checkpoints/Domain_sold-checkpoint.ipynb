# %% [markdown]
# #  Extracting data on Sold properties with Domain api
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Roudra Das    roudra.das@gmail.com                                            |
# | External References   | <a href="https://api.domain.com.au/" target="_blank">Domain API</a>|
# | Input Datasets        |  List Sold |
# | Output Datasets       |  Table|
# | Input Data Source     |  API |
# | Output Data Source    | Pandas Dataframe |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 15th May 2021 | Roudra Das | Notebook created to extract properties that have been sold in Australia|
#
# ## Other Details
# This Notebook is a prototype.

# %%
import pandas as pd
import requests
import json
import re, string, timeit
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = None # show all columns in display

# %% [markdown]
# ## Functions

# %%
def get_api_key(api_key_id = "Domain"):
  """
  Get the api key for website accessing.

  Table of key type and key value for privacy.

  Parameters
  ----------
  @api_key_id [string]: Key value in dataframe

  Returns
  -------
  [string]: client_id & client_secret

  """
  # load api keys file
  df_api_keys = pd.read_csv('../../api_keys.csv', header = 'infer')
  
  # return api key if in dataset
  try:
    # get api key from id
    client_id = df_api_keys.loc[df_api_keys['Id'] == api_key_id]['Client'].iloc[0] # get client by id
    client_secret = df_api_keys.loc[df_api_keys['Id'] == api_key_id]['Secret'].iloc[0] # get secret by id
    # return api key
    return client_id, client_secret
  except IndexError:
    # get api key id list
    api_key_id_list = df_api_keys['Id'].unique().tolist()
    # print error message
    print('Cannot map key. Api key id must be one of the following options {0}'.format(api_key_id_list))

# %%
# POST request for token
client_id, client_secret = get_api_key(api_key_id="Domain")
response = requests.post('https://auth.domain.com.au/v1/connect/token', data = {'client_id':client_id,"client_secret":client_secret,"grant_type":"client_credentials","scope":"api_listings_read","Content-Type":"text/json"})
token=response.json()
access_token=token["access_token"]

# %%
property_id="2016806821"
#domain_api_key = get_api_key(api_key_id = "Domain")
# GET Request for ID
url = "https://api.domain.com.au/v1/listings/"+property_id
auth = {"Authorization":"Bearer "+access_token}
request = requests.get(url,headers=auth)
r=request.json()

# %%
#get details
da=r['addressParts']
postcode=da['postcode']
suburb=da['suburb']
bathrooms=r['bathrooms']
bedrooms=r['bedrooms']
carspaces=r['carspaces']
property_type=r['propertyTypes']
area=r['landAreaSqm']
geolocation=r['geoLocation']
print(property_type, postcode, suburb, bedrooms, bathrooms,  carspaces, area, geolocation)

# the below puts all relevant property types into a single string. eg. a property listing can be a 'house' and a 'townhouse'
n=0
property_type_str=""
for p in r['propertyTypes']:
  property_type_str=property_type_str+(r['propertyTypes'][int(n)])
  n=n+1
print(property_type_str)
# Out:
# ['house'] 2640 Thurgoona 3 1 2 850 {'latitude': -36.0488277, 'longitude': 146.9899849}
# house

# %%
def api_property_list_sold(auth, property_type, bedrooms, bathrooms, suburb, postcode):
  # url for api
  url = "https://api.domain.com.au/v1/listings/residential/_search"

  # enter parameters
  post_fields ={
      "listingType":"Sold",
        "maxPrice":"",
        "pageSize":200,
      "propertyTypes":property_type,
      "minBedrooms":"",
        "maxBedrooms":"",
      "minBathrooms":"",
        "maxBathrooms":"",
      "locations":[
        {
          "state":"",
          "region":"",
          "area":"",
          "suburb":suburb,
          "postCode":postcode,
          "includeSurroundingSuburbs":False
        }
      ]
    }

  # response
  response = requests.post(url,headers=auth,json=post_fields)
  #response = requests.request("GET", url, headers=headers, params=querystring)
  return response.json()

# %%
def process_list_sold_response(response_json):
    """
    Process the list for sale API response.

    Convert each listing to a dataframe, append to a list, and concatenate to one dataframe.

    Parameters
    ----------
    @response_json [dictionary]: API response for list for sale

    Returns
    -------
    [dataframe] Dataframe of all list for sale responses

    """

    # empty dataframe
    dataframe_list = []

    # iterate through each for sale listing
    
    for j in range(len(response_json)):
        response_json[j]['listing']['propertyDetails']
        k = response_json[j]['listing']['propertyDetails'].copy()
        k['id']  = response_json[j]['listing']['id']
        if "soldPrice" in response_json[j]['listing']['soldData']:
            k['sold_price']  = response_json[j]['listing']['soldData']['soldPrice']
        else:
            k['sold_price']  = "NA"
        #k['sold_price'] = response.json[j]['listing']['hasVideo']
        # convert each listing to dataframe 
        _temp_df = pd.DataFrame.from_dict(k, orient='index').T

        # append to dataframe list for all listings
        dataframe_list.append(_temp_df)
    
        # concatenate all dataframes, for missing col values enter null value
    return pd.concat(dataframe_list, axis=0, ignore_index=True, sort=False)

# %%
property_list_sold_response = api_property_list_sold(auth, property_type, bedrooms, bathrooms, suburb, postcode)
property_list_sold_response[0:3]
# Out:
# [{'type': 'PropertyListing',
#   'listing': {'listingType': 'Sold',
#    'id': 2017635405,
#    'advertiser': {'type': 'Agency',
#     'id': 17470,
#     'name': 'PJ Murphy Real Estate',
#     'logoUrl': 'https://images.domain.com.au/img/Agencys/17470/logo_17470.gif?date=131781606321059129',
#     'preferredColourHex': '#0D1327',
#     'bannerUrl': 'https://images.domain.com.au/img/Agencys/17470/banner_17470.gif?date=131781606389806760',
#     'contacts': [{'name': 'Aaron Downie',
#       'photoUrl': 'https://images.domain.com.au/img/17470/contact_1820123.jpeg?mod=220419-151922'},
#      {'name': 'James Seymour',
#       'photoUrl': 'https://images.domain.com.au/img/17470/contact_1512731.jpeg?mod=220419-151922'}]},
#    'priceDetails': {'price': 1200000,
#     'priceFrom': 1200000,
#     'priceTo': 1200000,
#     'displayPrice': '$1,200,000'},
#    'media': [{'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017635405_3_1_220310_113313-w8000-h6000'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017635405_4_1_220302_101318-w1024-h683'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017635405_2_1_220310_113313-w4000-h3000'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017635405_25_1_220302_101318-w1024-h683'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017635405_1_1_220302_101318-w1024-h683'}],
#    'propertyDetails': {'state': 'NSW',
#     'features': ['Ensuite', 'SwimmingPool', 'Heating', 'RainwaterStorageTank'],
#     'propertyType': 'House',
#     'allPropertyTypes': ['House'],
#     'bathrooms': 2.0,
#     'bedrooms': 4.0,
#     'carspaces': 8,
#     'unitNumber': '',
#     'streetNumber': '4',
#     'street': 'Quandong Road',
#     'area': 'Albury - Greater Region',
#     'region': 'Regional NSW',
#     'suburb': 'THURGOONA',
#     'postcode': '2640',
#     'displayableAddress': '4 Quandong Road, Thurgoona',
#     'latitude': -36.04893,
#     'longitude': 146.976288,
#     'landArea': 3318.0,
#     'isRural': False,
#     'isNew': False,
#     'tags': []},
#    'headline': 'Luxurious, oversized, entertainer',
#    'summaryDescription': '<b></b><br />EXPRESSIONS OF INTEREST CLOSING DATE - 30/03/2022 AT 3PM. \n\nAn ultimate family compound of epic proportions and true resort-style living all set on 3318sqm of landscaped, low maintenance land this residence epitomises the very best in fami...',
#    'hasFloorplan': True,
#    'hasVideo': True,
#    'labels': ['Sold by private treaty 21 Apr 2022'],
#    'dateListed': '2022-03-03T09:13:20',
#    'inspectionSchedule': {'byAppointment': True,
#     'recurring': False,
#     'times': []},
#    'soldData': {'source': 'Agency',
#     'saleMethod': 'SoldByPrivateTreaty',
#     'soldDate': '2022-04-21',
#     'soldPrice': 1200000},
#    'listingSlug': '4-quandong-road-thurgoona-nsw-2640-2017635405'}},
#  {'type': 'PropertyListing',
#   'listing': {'listingType': 'Sold',
#    'id': 2017661945,
#    'advertiser': {'type': 'Agency',
#     'id': 35781,
#     'name': 'OBrien Real Estate Meehan Sanderson',
#     'logoUrl': 'https://images.domain.com.au/img/Agencys/35781/logo_35781.jpeg',
#     'preferredColourHex': '#19202a',
#     'bannerUrl': 'https://images.domain.com.au/img/Agencys/35781/banner_35781.jpeg',
#     'contacts': [{'name': 'Tom Sanderson'}, {'name': 'Vanessa Meehan'}]},
#    'priceDetails': {'price': 629000,
#     'priceFrom': 629000,
#     'priceTo': 629000,
#     'displayPrice': '$629,000'},
#    'media': [{'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661945_1_1_220315_124300-w2000-h1500'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661945_2_1_220315_124300-w2000-h1500'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661945_3_1_220315_124300-w2000-h1500'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661945_4_1_220315_124300-w2000-h1500'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661945_5_1_220315_124300-w2000-h1500'}],
#    'propertyDetails': {'state': 'NSW',
#     'features': ['AirConditioning',
#      'BuiltInWardrobes',
#      'Ensuite',
#      'SecureParking',
#      'NorthFacing',
#      'Bath',
#      'Heating',
#      'Dishwasher'],
#     'propertyType': 'House',
#     'allPropertyTypes': ['House'],
#     'bathrooms': 2.0,
#     'bedrooms': 4.0,
#     'carspaces': 2,
#     'unitNumber': '',
#     'streetNumber': '16',
#     'street': 'Stockyard Way',
#     'area': 'Albury - Greater Region',
#     'region': 'Regional NSW',
#     'suburb': 'THURGOONA',
#     'postcode': '2640',
#     'displayableAddress': '16 Stockyard Way, Thurgoona',
#     'latitude': -36.0579224,
#     'longitude': 146.9769,
#     'landArea': 630.0,
#     'isRural': False,
#     'isNew': False,
#     'tags': []},
#    'headline': 'Quality Home With Caravan Access',
#    'summaryDescription': '<b></b><br />Situated in the popular suburb of Thurgoona this new near home has been built with quality fixtures and fittings throughout. With fresh paint, vinyl floors, wide front door, and ducted vacuum system this home has been wisely upgraded to ac...',
#    'hasFloorplan': True,
#    'hasVideo': False,
#    'labels': ['Sold by private treaty 24 Mar 2022'],
#    'dateListed': '2022-03-15T11:20:55',
#    'inspectionSchedule': {'byAppointment': True,
#     'recurring': False,
#     'times': []},
#    'soldData': {'source': 'Apm',
#     'saleMethod': 'SoldByPrivateTreaty',
#     'soldDate': '2022-03-24',
#     'soldPrice': 629000},
#    'listingSlug': '16-stockyard-way-thurgoona-nsw-2640-2017661945'}},
#  {'type': 'PropertyListing',
#   'listing': {'listingType': 'Sold',
#    'id': 2017661593,
#    'advertiser': {'type': 'Agency',
#     'id': 11871,
#     'name': 'Link Real Estate',
#     'logoUrl': 'https://images.domain.com.au/img/Agencys/11871/logo_11871.GIF?date=2015-09-23-11-08-21',
#     'preferredColourHex': '#535152',
#     'bannerUrl': 'https://images.domain.com.au/img/Agencys/11871/banner_11871.GIF',
#     'contacts': [{'name': 'Brent Booker'}]},
#    'priceDetails': {'displayPrice': 'Price Withheld'},
#    'media': [{'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661593_1_1_220314_104448-w4646-h3098'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661593_2_1_220314_104448-w5000-h3334'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661593_3_1_220314_104448-w5000-h3334'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661593_4_1_220314_104448-w5000-h3334'},
#     {'category': 'Image',
#      'url': 'https://bucket-api.domain.com.au/v1/bucket/image/2017661593_5_1_220314_104448-w5000-h3334'}],
#    'propertyDetails': {'state': 'NSW',
#     'features': ['BuiltInWardrobes',
#      'Ensuite',
#      'Gas',
#      'SecureParking',
#      'Bath',
#      'Heating',
#      'Dishwasher',
#      'FullyFenced',
#      'SolarPanels'],
#     'propertyType': 'House',
#     'allPropertyTypes': ['House'],
#     'bathrooms': 2.0,
#     'bedrooms': 4.0,
#     'carspaces': 2,
#     'unitNumber': '',
#     'streetNumber': '10',
#     'street': 'Friarbird Way',
#     'area': 'Albury - Greater Region',
#     'region': 'Regional NSW',
#     'suburb': 'THURGOONA',
#     'postcode': '2640',
#     'displayableAddress': '10 Friarbird Way, Thurgoona',
#     'latitude': -36.03671,
#     'longitude': 146.980148,
#     'landArea': 531.0,
#     'isRural': False,
#     'isNew': False,
#     'tags': []},
#    'headline': 'Immaculately presented family home',
#    'summaryDescription': '<b></b><br />An immaculately presented and ideally located family home will cater to owner occupiers, retirees or the savvy investor. Positioned on a comfortable allotment of  531 sqm providing space for both formal and informal entertaining this magni...',
#    'hasFloorplan': True,
#    'hasVideo': False,
#    'labels': ['Sold by private treaty 20 Apr 2022'],
#    'dateListed': '2022-03-15T09:45:08',
#    'inspectionSchedule': {'byAppointment': False,
#     'recurring': False,
#     'times': []},
#    'soldData': {'source': 'Agency',
#     'saleMethod': 'SoldByPrivateTreaty',
#     'soldDate': '2022-04-20'},
#    'listingSlug': '10-friarbird-way-thurgoona-nsw-2640-2017661593'}}]

# %%
df_properties_sold_raw = process_list_sold_response(response_json=property_list_sold_response)
df_properties_sold_raw = df_properties_sold_raw.drop(['allPropertyTypes','buildingArea'], axis = 1)
df_properties_sold_raw = df_properties_sold_raw[df_properties_sold_raw.sold_price !="NA"]
df_properties_sold_raw = df_properties_sold_raw.dropna()
df_properties_sold_raw.landArea = df_properties_sold_raw.landArea.astype(int)
df_properties_sold_raw.sold_price = df_properties_sold_raw.sold_price.astype(int)
df_properties_sold_raw.bathrooms = df_properties_sold_raw.bathrooms.astype(int)
df_properties_sold_raw.bedrooms = df_properties_sold_raw.bedrooms.astype(int)
df_properties_sold_raw.carspaces = df_properties_sold_raw.carspaces.astype(int)
df_properties_sold_raw['URL'] = 'http://www.domain.com.au/' + df_properties_sold_raw.id.apply(str)

# %%
df_properties_sold_raw.to_csv("output/Sold_Properties.csv", index = False)

# %%
def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}"">{}</a>'.format(val, val)

# %%
df_properties_sold = df_properties_sold_raw.style.format({'URL': make_clickable})
df_properties_sold
# Out:
# <style type="text/css">
# </style>
# <table id="T_62ade">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62ade_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_62ade_level0_col1" class="col_heading level0 col1" >features</th>
#       <th id="T_62ade_level0_col2" class="col_heading level0 col2" >propertyType</th>
#       <th id="T_62ade_level0_col3" class="col_heading level0 col3" >bathrooms</th>
#       <th id="T_62ade_level0_col4" class="col_heading level0 col4" >bedrooms</th>
#       <th id="T_62ade_level0_col5" class="col_heading level0 col5" >carspaces</th>
#       <th id="T_62ade_level0_col6" class="col_heading level0 col6" >unitNumber</th>
#       <th id="T_62ade_level0_col7" class="col_heading level0 col7" >streetNumber</th>
#       <th id="T_62ade_level0_col8" class="col_heading level0 col8" >street</th>
#       <th id="T_62ade_level0_col9" class="col_heading level0 col9" >area</th>
#       <th id="T_62ade_level0_col10" class="col_heading level0 col10" >region</th>
#       <th id="T_62ade_level0_col11" class="col_heading level0 col11" >suburb</th>
#       <th id="T_62ade_level0_col12" class="col_heading level0 col12" >postcode</th>
#       <th id="T_62ade_level0_col13" class="col_heading level0 col13" >displayableAddress</th>
#       <th id="T_62ade_level0_col14" class="col_heading level0 col14" >latitude</th>
#       <th id="T_62ade_level0_col15" class="col_heading level0 col15" >longitude</th>
#       <th id="T_62ade_level0_col16" class="col_heading level0 col16" >landArea</th>
#       <th id="T_62ade_level0_col17" class="col_heading level0 col17" >isRural</th>
#       <th id="T_62ade_level0_col18" class="col_heading level0 col18" >isNew</th>
#       <th id="T_62ade_level0_col19" class="col_heading level0 col19" >tags</th>
#       <th id="T_62ade_level0_col20" class="col_heading level0 col20" >id</th>
#       <th id="T_62ade_level0_col21" class="col_heading level0 col21" >sold_price</th>
#       <th id="T_62ade_level0_col22" class="col_heading level0 col22" >URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62ade_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62ade_row0_col0" class="data row0 col0" >NSW</td>
#       <td id="T_62ade_row0_col1" class="data row0 col1" >['Ensuite', 'SwimmingPool', 'Heating', 'RainwaterStorageTank']</td>
#       <td id="T_62ade_row0_col2" class="data row0 col2" >House</td>
#       <td id="T_62ade_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_62ade_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_62ade_row0_col5" class="data row0 col5" >8</td>
#       <td id="T_62ade_row0_col6" class="data row0 col6" ></td>
#       <td id="T_62ade_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_62ade_row0_col8" class="data row0 col8" >Quandong Road</td>
#       <td id="T_62ade_row0_col9" class="data row0 col9" >Albury - Greater Region</td>
#       <td id="T_62ade_row0_col10" class="data row0 col10" >Regional NSW</td>
#       <td id="T_62ade_row0_col11" class="data row0 col11" >THURGOONA</td>
#       <td id="T_62ade_row0_col12" class="data row0 col12" >2640</td>
#       <td id="T_62ade_row0_col13" class="data row0 col13" >4 Quandong Road, Thurgoona</td>
#       <td id="T_62ade_row0_col14" class="data row0 col14" >-36.048930</td>
#       <td id="T_62ade_row0_col15" class="data row0 col15" >146.976288</td>
#       <td id="T_62ade_row0_col16" class="data row0 col16" >3318</td>
#       <td id="T_62ade_row0_col17" class="data row0 col17" >False</td>
#       <td id="T_62ade_row0_col18" class="data row0 col18" >False</td>
#       <td id="T_62ade_row0_col19" class="data row0 col19" >[]</td>
#       <td id="T_62ade_row0_col20" class="data row0 col20" >2017635405</td>
#       <td id="T_62ade_row0_col21" class="data row0 col21" >1200000</td>
#       <td id="T_62ade_row0_col22" class="data row0 col22" ><a target="_blank" href="http://www.domain.com.au/2017635405"">http://www.domain.com.au/2017635405</a></td>
#     </tr>
#     <tr>
#       <th id="T_62ade_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_62ade_row1_col0" class="data row1 col0" >NSW</td>
#       <td id="T_62ade_row1_col1" class="data row1 col1" >['AirConditioning', 'BuiltInWardrobes', 'Ensuite', 'SecureParking', 'NorthFacing', 'Bath', 'Heating', 'Dishwasher']</td>
#       <td id="T_62ade_row1_col2" class="data row1 col2" >House</td>
#       <td id="T_62ade_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_62ade_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_62ade_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_62ade_row1_col6" class="data row1 col6" ></td>
#       <td id="T_62ade_row1_col7" class="data row1 col7" >16</td>
#       <td id="T_62ade_row1_col8" class="data row1 col8" >Stockyard Way</td>
#       <td id="T_62ade_row1_col9" class="data row1 col9" >Albury - Greater Region</td>
#       <td id="T_62ade_row1_col10" class="data row1 col10" >Regional NSW</td>
#       <td id="T_62ade_row1_col11" class="data row1 col11" >THURGOONA</td>
#       <td id="T_62ade_row1_col12" class="data row1 col12" >2640</td>
#       <td id="T_62ade_row1_col13" class="data row1 col13" >16 Stockyard Way, Thurgoona</td>
#       <td id="T_62ade_row1_col14" class="data row1 col14" >-36.057922</td>
#       <td id="T_62ade_row1_col15" class="data row1 col15" >146.976900</td>
#       <td id="T_62ade_row1_col16" class="data row1 col16" >630</td>
#       <td id="T_62ade_row1_col17" class="data row1 col17" >False</td>
#       <td id="T_62ade_row1_col18" class="data row1 col18" >False</td>
#       <td id="T_62ade_row1_col19" class="data row1 col19" >[]</td>
#       <td id="T_62ade_row1_col20" class="data row1 col20" >2017661945</td>
#       <td id="T_62ade_row1_col21" class="data row1 col21" >629000</td>
#       <td id="T_62ade_row1_col22" class="data row1 col22" ><a target="_blank" href="http://www.domain.com.au/2017661945"">http://www.domain.com.au/2017661945</a></td>
#     </tr>
#     <tr>
#       <th id="T_62ade_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_62ade_row2_col0" class="data row2 col0" >NSW</td>
#       <td id="T_62ade_row2_col1" class="data row2 col1" >['BuiltInWardrobes', 'Ensuite', 'Gas', 'Dishwasher', 'Shed']</td>
#       <td id="T_62ade_row2_col2" class="data row2 col2" >House</td>
#       <td id="T_62ade_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_62ade_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_62ade_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_62ade_row2_col6" class="data row2 col6" ></td>
#       <td id="T_62ade_row2_col7" class="data row2 col7" >8</td>
#       <td id="T_62ade_row2_col8" class="data row2 col8" >Oak Court</td>
#       <td id="T_62ade_row2_col9" class="data row2 col9" >Albury - Greater Region</td>
#       <td id="T_62ade_row2_col10" class="data row2 col10" >Regional NSW</td>
#       <td id="T_62ade_row2_col11" class="data row2 col11" >THURGOONA</td>
#       <td id="T_62ade_row2_col12" class="data row2 col12" >2640</td>
#       <td id="T_62ade_row2_col13" class="data row2 col13" >8 Oak Court, Thurgoona</td>
#       <td id="T_62ade_row2_col14" class="data row2 col14" >-36.051760</td>
#       <td id="T_62ade_row2_col15" class="data row2 col15" >146.980835</td>
#       <td id="T_62ade_row2_col16" class="data row2 col16" >852</td>
#       <td id="T_62ade_row2_col17" class="data row2 col17" >False</td>
#       <td id="T_62ade_row2_col18" class="data row2 col18" >False</td>
#       <td id="T_62ade_row2_col19" class="data row2 col19" >[]</td>
#       <td id="T_62ade_row2_col20" class="data row2 col20" >2017636403</td>
#       <td id="T_62ade_row2_col21" class="data row2 col21" >430000</td>
#       <td id="T_62ade_row2_col22" class="data row2 col22" ><a target="_blank" href="http://www.domain.com.au/2017636403"">http://www.domain.com.au/2017636403</a></td>
#     </tr>
#     <tr>
#       <th id="T_62ade_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_62ade_row3_col0" class="data row3 col0" >NSW</td>
#       <td id="T_62ade_row3_col1" class="data row3 col1" >['BuiltInWardrobes', 'Ensuite', 'Gas', 'Secu

# %% [markdown]
# Data Exploration

# %%
df_properties_sold_raw.sold_price.describe()
# Out:
# count    1.850000e+02
# mean     5.549034e+05
# std      1.784498e+05
# min      2.300000e+05
# 25%      4.300000e+05
# 50%      5.400000e+05
# 75%      6.300000e+05
# max      1.525000e+06
# Name: sold_price, dtype: float64

# %%
import matplotlib.pyplot as plt

corrmat = df_properties_sold_raw.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
import plotly.express as px

fig = px.scatter_mapbox(df_properties_sold_raw, lat="latitude", lon="longitude", hover_name="id",size = "sold_price", hover_data=["propertyType", "bedrooms", "bathrooms", "landArea"],zoom=15, height=600)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# # End of Notebook
